# %% [markdown]
# # Team Baseline - Average
#
# This baseline model computes the average number of points of the previous N years and use it as a prediction to the N+1 year.

# %%
# Imports

import pandas as pd
import numpy as np
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from team_dataloader import *

# %%
dataset = get_team_dataset()
print(len(dataset))
team_data_loader = DataLoader(dataset=dataset, batch_size=1) # Batch size of 1 to load one data element at a time
# Out:
# 637

# %%
print(dataset.__getitem__(1))
print(len(dataset.__getitem__(0)))
print("Features")
print(dataset.__getitem__(1)[0])
print(dataset.__getitem__(1)[0].shape)
print("Target")
print(dataset.__getitem__(1)[1])
print(dataset.__getitem__(1)[1].shape)

# Compare to true data
print("True Target")
print(dataset.dataset_with_names[1][1])

# Mean accross columns
x = dataset.__getitem__(1)[0]
print(torch.mean(x, dim=0))
# Out:
# (tensor([[0.2200, 2.3900, 4.7300],
#         [0.2400, 2.4400, 3.6300],
#         [0.2500, 2.3300, 3.5500],
#         [0.4700, 2.7600, 2.8500],
#         [0.5060, 2.3500, 2.4400]]), tensor([0.6280, 2.9100, 2.1800]))
# 2
# Features
# tensor([[0.2200, 2.3900, 4.7300],
#         [0.2400, 2.4400, 3.6300],
#         [0.2500, 2.3300, 3.5500],
#         [0.4700, 2.7600, 2.8500],
#         [0.5060, 2.3500, 2.4400]])
# torch.Size([5, 3])
# Target
# tensor([0.6280, 2.9100, 2.1800])
# torch.Size([3])
# True Target
#            team name   PTS%  GF/G  GA/G  Season
# 220  Ottawa Senators  0.628  2.91  2.18    1999
# tensor([0.3372, 2.4540, 3.4400])

# %%
# Get predictions
predictions = []
targets = []


for step, (x,y) in enumerate(team_data_loader):
    predictions.append(torch.mean(x, dim=1))
    targets.append(y)

predictions = torch.stack(predictions)
targets = torch.stack(targets)

print(predictions)
print(targets)
# Out:
# [tensor([[0.2646, 2.4640, 3.8920]]), tensor([[0.3372, 2.4540, 3.4400]]), tensor([[0.4188, 2.5580, 2.9300]]), tensor([[0.4866, 2.6660, 2.7160]]), tensor([[0.5696, 2.8680, 2.5060]]), tensor([[0.5902, 2.9080, 2.4440]]), tensor([[0.6268, 3.0800, 2.4000]]), tensor([[0.5962, 3.1440, 2.7480]]), tensor([[0.5486, 2.8480, 2.8460]]), tensor([[0.5328, 2.7420, 2.8960]]), tensor([[0.5348, 2.5780, 2.7220]]), tensor([[0.5410, 2.6160, 2.7880]]), tensor([[0.5472, 2.6460, 2.7280]]), tensor([[0.5606, 2.7420, 2.7180]]), tensor([[0.5680, 2.6520, 2.6540]]), tensor([[0.5332, 2.7200, 2.9300]]), tensor([[0.5038, 2.7520, 3.0340]]), tensor([[0.4704, 2.7220, 3.1960]]), tensor([[0.4578, 2.7160, 3.2840]]), tensor([[0.4272, 2.7600, 3.4160]]), tensor([[0.4502, 2.8580, 3
, 2.7560, 3.1780]]), tensor([[0.5036, 2.7440, 3.1240]]), tensor([[0.4926, 2.7180, 3.1700]]), tensor([[0.4894, 2.7900, 3.1340]]), tensor([[0.5322, 2.8520, 2.9880]]), tensor([[0.5664, 2.9640, 2.8720]]), tensor([[0.5590, 2.9220, 2.7840]]), tensor([[0.5712, 2.9160, 2.6520]]), tensor([[0.6256, 3.0120, 2.6100]]), tensor([[0.6584, 3.2240, 2.6400]]), tensor([[0.6580, 3.2860, 2.6920]]), tensor([[0.6738, 3.3820, 2.7280]]), tensor([[0.6934, 3.5180, 2.7380]]), tensor([[0.6752, 3.4920, 2.7820]]), tensor([[0.4226, 3.1180, 3.6320]]), tensor([[0.4060, 2.9600, 3.5500]]), tensor([[0.4088, 2.9420, 3.4920]]), tensor([[0.5158, 2.5780, 2.6300]]), tensor([[0.5000, 2.5080, 2.6820]]), tensor([[0.5720, 3.0240, 2.9860]]), tensor([[0.5464, 2.8900, 2.9260]]), tensor([[0.5390, 2.8200, 2.9000]]), tensor([[0.5144, 2.7400, 2.9620]]), tensor([[0.4974, 2.6640, 2.9740]]), tensor([[0.4864, 2.5580, 2.8960]]), tensor([[0.4802, 2.4720, 2.8660]]), tensor([[0.4862, 2.4720, 2.8480]]), tensor([[0.4998, 2.4900, 2.8040]]), tensor([[0.5194, 2.5820, 2.7920]]), tensor([[0.5520, 2.7740, 2.8260]]), tensor([[0.5900, 2.9220, 2.7640]]), tensor([[0.6254, 3.0800, 2.6920]]), tensor([[0.6620, 3.1720, 2.5860]]), ten ...
# tensor([[[0.2646, 2.4640, 3.8920]],
#
#         [[0.3372, 2.4540, 3.4400]],
#
#         [[0.4188, 2.5580, 2.9300]],
#
#         ...,
#
#         [[0.5670, 2.5880, 2.6440]],
#
#         [[0.5720, 2.5820, 2.6160]],
#
#         [[0.5144, 2.9300, 3.1840]]])
# tensor([[[0.5060, 2.3500, 2.4400]],
#
#         [[0.6280, 2.9100, 2.1800]],
#
#         [[0.5790, 2.9800, 2.5600]],
#
#         ...,
#
#         [[0.5310, 2.5200, 2.6000]],
#
#         [[0.5430, 2.5600, 2.7300]],
#
#         [[0.4880, 2.6600, 3.2000]]])

# %%
# Define loss
def RMSELoss(yhat, y):
    return torch.sqrt(torch.mean((yhat-y)**2))

# %%
# Calculate the loss over all samples
print(predictions)

loss = RMSELoss(predictions, targets)

print(loss)
# Out:
# tensor([[[0.2646, 2.4640, 3.8920]],
#
#         [[0.3372, 2.4540, 3.4400]],
#
#         [[0.4188, 2.5580, 2.9300]],
#
#         ...,
#
#         [[0.5670, 2.5880, 2.6440]],
#
#         [[0.5720, 2.5820, 2.6160]],
#
#         [[0.5144, 2.9300, 3.1840]]])
# tensor(0.3085)
